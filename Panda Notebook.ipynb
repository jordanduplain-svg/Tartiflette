# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\jorda\\PycharmProjects\\Projet Arbre\\data\\trees\\arbres.csv")

# %%
print (df.head(2))
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        34835.0  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1        34836.0  ESP36319  AR36319   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP151     Arbre de voirie      ESP237  ...
# 1          Arbre         ESP151     Arbre de voirie      ESP237  ...
#
#   diametrearbre  causeabattage              collectivite stationmetro  \
# 0           NaN            NaN  Grenoble Alpes Métropole          NaN
# 1           NaN            NaN  Grenoble Alpes Métropole          NaN
#
#   hauteurarbre portarbre              structure  forme typenature  \
# 0          NaN       NaN  Métropole de Grenoble    NaN        NaN
# 1          NaN       NaN  Métropole de Grenoble    NaN        NaN
#
#                            geo_point_2d
# 0  45.167098421885385,5.740131798404362
# 1   45.16710682038838,5.740199792549315
#
# ...

# %%
df0= df.head(2)
df0["code"]
# Out:
# 0    ESP36318
# 1    ESP36319
# Name: code, dtype: object

# %%
df["anneedeplantation"]
# Out:
# 0        2015.0
# 1        2015.0
# 2        2015.0
# 3        2015.0
# 4        2015.0
#           ...
# 31666    2018.0
# 31667       NaN
# 31668       NaN
# 31669       NaN
# 31670       NaN
# Name: anneedeplantation, Length: 31671, dtype: float64

# %%
df.iloc[0:50]
# Out:
#     elem_point_id      code      nom genre  genre_desc categorie  \
# 0         34835.0  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1         34836.0  ESP36319  AR36319   VEG  VEGETATION     ESP01
# 2         34837.0  ESP36320  AR36320   VEG  VEGETATION     ESP01
# 3         34838.0  ESP36321  AR36321   VEG  VEGETATION     ESP01
# 4         34839.0  ESP36322  AR36322   VEG  VEGETATION     ESP01
# 5         34840.0  ESP36323  AR36323   VEG  VEGETATION     ESP01
# 6         34841.0  ESP36324  AR36324   VEG  VEGETATION     ESP01
# 7         34842.0  ESP36325  AR36325   VEG  VEGETATION     ESP01
# 8         34843.0  ESP36326  AR36326   VEG  VEGETATION     ESP01
# 9         34844.0  ESP36327  AR36327   VEG  VEGETATION     ESP01
# 10        34845.0  ESP36328  AR36328   VEG  VEGETATION     ESP01
# 11        34846.0  ESP36329  AR36329   VEG  VEGETATION     ESP01
# 12        16799.0  ESP19333  AR19333   VEG  VEGETATION     ESP01
# ...

# %%
df.tail(50)
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 31621        45252.0  ESP41045  AR41045   VEG  VEGETATION     ESP01
# 31622        45253.0  ESP41046  AR41046   VEG  VEGETATION     ESP01
# 31623        45254.0  ESP41047  AR41047   VEG  VEGETATION     ESP01
# 31624        45255.0  ESP41048  AR41048   VEG  VEGETATION     ESP01
# 31625        45256.0  ESP41049  AR41049   VEG  VEGETATION     ESP01
# 31626        45257.0  ESP41050  AR41050   VEG  VEGETATION     ESP01
# 31627        45258.0  ESP41051  AR41051   VEG  VEGETATION     ESP01
# 31628        45259.0  ESP41052  AR41052   VEG  VEGETATION     ESP01
# 31629        45260.0  ESP41053  AR41053   VEG  VEGETATION     ESP01
# 31630        45261.0  ESP41054  AR41054   VEG  VEGETATION     ESP01
# 31631        34954.0  ESP36405  AR36405   VEG  VEGETATION     ESP01
# 31632        34955.0  ESP36406  AR36406   VEG  VEGETATION     ESP01
# 31633        34956.0  ESP36407  AR36407   VEG  VEGETATION     ESP01
# ...

# %%
row=df.shape
print({row})
# Out:
# {(31671, 38)}

# %%
df0=df["anneedeplantation"].dropna()
row1=df0.shape
print({row1})
# Out:
# {(29526,)}

# %%
max = df["anneedeplantation"].max()
print (max)
min = df["anneedeplantation"].min()
print(min)
# Out:
# 2024.0
# 1900.0

# %%
df.sort_values('anneedeplantation')
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 22271        44573.0  ESP40648  AR40648   VEG  VEGETATION     ESP01
# 22270        44572.0  ESP40647  AR40647   VEG  VEGETATION     ESP01
# 22277        44585.0  ESP40660  AR40660   VEG  VEGETATION     ESP01
# 22272        44574.0  ESP40649  AR40649   VEG  VEGETATION     ESP01
# 22278        44588.0  ESP40663  AR40663   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31630        45261.0  ESP41054  AR41054   VEG  VEGETATION     ESP01
# 31667        44841.0  ESP40796  AR40796   VEG  VEGETATION     ESP01
# 31668        44842.0  ESP40797  AR40797   VEG  VEGETATION     ESP01
# 31669        44982.0  ESP40913  AR40913   VEG  VEGETATION     ESP01
# 31670            NaN       NaN      NaN   NaN         NaN       NaN
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
df1=df.drop(df[df['anneedeplantation']=='1988'].index)
df1.drop(df1[df1['anneedeplantation']=='2024'].index)
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 0            34835.0  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1            34836.0  ESP36319  AR36319   VEG  VEGETATION     ESP01
# 2            34837.0  ESP36320  AR36320   VEG  VEGETATION     ESP01
# 3            34838.0  ESP36321  AR36321   VEG  VEGETATION     ESP01
# 4            34839.0  ESP36322  AR36322   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31666        44742.0  ESP40745  AR40745   VEG  VEGETATION     ESP01
# 31667        44841.0  ESP40796  AR40796   VEG  VEGETATION     ESP01
# 31668        44842.0  ESP40797  AR40797   VEG  VEGETATION     ESP01
# 31669        44982.0  ESP40913  AR40913   VEG  VEGETATION     ESP01
# 31670            NaN       NaN      NaN   NaN         NaN       NaN
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
df['anneedeplantation']-df["anneedeplantation"].min()
# Out:
# 0        115.0
# 1        115.0
# 2        115.0
# 3        115.0
# 4        115.0
#          ...
# 31666    118.0
# 31667      NaN
# 31668      NaN
# 31669      NaN
# 31670      NaN
# Name: anneedeplantation, Length: 31671, dtype: float64

# %%
df.mean(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.mean(axis=0)
#
# File ~\PycharmProjects\JupyterProject\.venv\Lib\site-packages\pandas\core\frame.py:11700, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11692 @doc(make_doc("mean", ndim=2))
#   11693 def mean(
#   11694     self,
#    (...)  11698     **kwargs,
#   11699 ):
# > 11700     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11701     if isinstance(result, Series):
#   11702         result = result.__finalize__(self, method="mean")
#
# File ~\PycharmProjects\JupyterProject\.venv\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# ...
